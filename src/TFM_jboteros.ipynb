# %% [markdown]
# <h1>MODELIZACIÓN PREDICTIVA: SINIESTRALIDAD EN SEGUROS DE ASISTENCIA EN VIAJES<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introducción</a></span></li><li><span><a href="#Carga-del-conjunto-de-datos" data-toc-modified-id="Carga-del-conjunto-de-datos-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Carga del conjunto de datos</a></span><ul class="toc-item"><li><span><a href="#Importar-librerias-a-utilizar" data-toc-modified-id="Importar-librerias-a-utilizar-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importar librerias a utilizar</a></span></li><li><span><a href="#Cargar-archivo-de-datos-Travel-Insurance" data-toc-modified-id="Cargar-archivo-de-datos-Travel-Insurance-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cargar archivo de datos Travel Insurance</a></span></li></ul></li><li><span><a href="#Análisis-de-los-datos" data-toc-modified-id="Análisis-de-los-datos-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Análisis de los datos</a></span><ul class="toc-item"><li><span><a href="#Análisis-estadístico-básico" data-toc-modified-id="Análisis-estadístico-básico-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Análisis estadístico básico</a></span></li><li><span><a href="#Análisis-exploratorio-de-los-datos" data-toc-modified-id="Análisis-exploratorio-de-los-datos-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Análisis exploratorio de los datos</a></span></li></ul></li><li><span><a href="#Preparación-y-Limpeza-de-los-datos" data-toc-modified-id="Preparación-y-Limpeza-de-los-datos-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Preparación y Limpeza de los datos</a></span></li><li><span><a href="#Selección-de-Variables" data-toc-modified-id="Selección-de-Variables-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Selección de Variables</a></span><ul class="toc-item"><li><span><a href="#Train-y-test-data" data-toc-modified-id="Train-y-test-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Train y test data</a></span></li><li><span><a href="#ANOVA" data-toc-modified-id="ANOVA-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ANOVA</a></span></li><li><span><a href="#Boruta" data-toc-modified-id="Boruta-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Boruta</a></span></li><li><span><a href="#Reducción-de-la-dimensionalidad-(PCA)" data-toc-modified-id="Reducción-de-la-dimensionalidad-(PCA)-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Reducción de la dimensionalidad (PCA)</a></span></li></ul></li><li><span><a href="#Aplicación-de-modelos" data-toc-modified-id="Aplicación-de-modelos-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Aplicación de modelos</a></span><ul class="toc-item"><li><span><a href="#Resample-sobre-Train-data" data-toc-modified-id="Resample-sobre-Train-data-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Resample sobre Train data</a></span><ul class="toc-item"><li><span><a href="#SMOTE---Random-Undersample" data-toc-modified-id="SMOTE---Random-Undersample-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>SMOTE - Random Undersample</a></span></li><li><span><a href="#SMOTETomek" data-toc-modified-id="SMOTETomek-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>SMOTETomek</a></span></li></ul></li><li><span><a href="#Regresión-Logística" data-toc-modified-id="Regresión-Logística-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Regresión Logística</a></span><ul class="toc-item"><li><span><a href="#Optimización-del-modelo" data-toc-modified-id="Optimización-del-modelo-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Optimización del modelo</a></span></li></ul></li><li><span><a href="#Combinación-paralela-de-clasificadores" data-toc-modified-id="Combinación-paralela-de-clasificadores-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Combinación paralela de clasificadores</a></span><ul class="toc-item"><li><span><a href="#Bagging" data-toc-modified-id="Bagging-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Bagging</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#Gradient-Boosting" data-toc-modified-id="Gradient-Boosting-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Gradient Boosting</a></span></li><li><span><a href="#Extreme-Gradient-Boosting" data-toc-modified-id="Extreme-Gradient-Boosting-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Extreme Gradient Boosting</a></span></li><li><span><a href="#Easy-Ensemble-(combines-bagging-and-boosting)" data-toc-modified-id="Easy-Ensemble-(combines-bagging-and-boosting)-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Easy Ensemble (combines bagging and boosting)</a></span></li></ul></li><li><span><a href="#Combinación-secuencial-de-clasificadores-base-diferentes" data-toc-modified-id="Combinación-secuencial-de-clasificadores-base-diferentes-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Combinación secuencial de clasificadores base diferentes</a></span><ul class="toc-item"><li><span><a href="#Arbol-de-decisión" data-toc-modified-id="Arbol-de-decisión-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Arbol de decisión</a></span></li><li><span><a href="#SVM" data-toc-modified-id="SVM-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>SVM</a></span></li><li><span><a href="#KNN" data-toc-modified-id="KNN-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>KNN</a></span></li><li><span><a href="#Stacking" data-toc-modified-id="Stacking-6.4.4"><span class="toc-item-num">6.4.4&nbsp;&nbsp;</span>Stacking</a></span></li></ul></li><li><span><a href="#AutoML" data-toc-modified-id="AutoML-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>AutoML</a></span><ul class="toc-item"><li><span><a href="#Modelo-AutoML-1:-Tree-based-Pipeline-Optimization-Tool-(TPOT)" data-toc-modified-id="Modelo-AutoML-1:-Tree-based-Pipeline-Optimization-Tool-(TPOT)-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Modelo AutoML 1: Tree-based Pipeline Optimization Tool (TPOT)</a></span><ul class="toc-item"><li><span><a href="#Evaluación-del-modelo" data-toc-modified-id="Evaluación-del-modelo-6.5.1.1"><span class="toc-item-num">6.5.1.1&nbsp;&nbsp;</span>Evaluación del modelo</a></span></li><li><span><a href="#Evaluación-del-modelo-con-resample" data-toc-modified-id="Evaluación-del-modelo-con-resample-6.5.1.2"><span class="toc-item-num">6.5.1.2&nbsp;&nbsp;</span>Evaluación del modelo con resample</a></span></li></ul></li><li><span><a href="#Modelo-AutoML-2:-Hyperopt-Sklearn" data-toc-modified-id="Modelo-AutoML-2:-Hyperopt-Sklearn-6.5.2"><span class="toc-item-num">6.5.2&nbsp;&nbsp;</span>Modelo AutoML 2: Hyperopt-Sklearn</a></span><ul class="toc-item"><li><span><a href="#Evaluación-del-modelo" data-toc-modified-id="Evaluación-del-modelo-6.5.2.1"><span class="toc-item-num">6.5.2.1&nbsp;&nbsp;</span>Evaluación del modelo</a></span></li><li><span><a href="#Evaluación-del-modelo-con-resample" data-toc-modified-id="Evaluación-del-modelo-con-resample-6.5.2.2"><span class="toc-item-num">6.5.2.2&nbsp;&nbsp;</span>Evaluación del modelo con resample</a></span></li></ul></li><li><span><a href="#Modelo-AutoML-3:-Auto-Sklearn" data-toc-modified-id="Modelo-AutoML-3:-Auto-Sklearn-6.5.3"><span class="toc-item-num">6.5.3&nbsp;&nbsp;</span>Modelo AutoML 3: Auto-Sklearn</a></span><ul class="toc-item"><li><span><a href="#Evaluación-del-modelo" data-toc-modified-id="Evaluación-del-modelo-6.5.3.1"><span class="toc-item-num">6.5.3.1&nbsp;&nbsp;</span>Evaluación del modelo</a></span></li><li><span><a href="#Evaluación-del-modelo-con-resample" data-toc-modified-id="Evaluación-del-modelo-con-resample-6.5.3.2"><span class="toc-item-num">6.5.3.2&nbsp;&nbsp;</span>Evaluación del modelo con resample</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Introducción

# %% [markdown]
# https://towardsdatascience.com/imbalanced-class-sizes-and-classification-models-a-cautionary-tale-3648b8586e03
#
# https://towardsdatascience.com/imbalanced-class-sizes-and-classification-models-a-cautionary-tale-part-2-cf371500d1b3

# %% [markdown]
# # Carga del conjunto de datos

# %% [markdown]
# ## Importar librerias a utilizar

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
import matplotlib.ticker as ticker
import csv
import io
import os
import re
from numpy import mean
from sklearn import preprocessing
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
import itertools

import warnings
warnings.filterwarnings("ignore")

sns.set(color_codes=True)
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# ## Cargar archivo de datos Travel Insurance

# %%
travel_data = pd.read_csv('../data/travel insurance.csv')

# %%
#Visualizamos las primeros 15 muestras del set de datos

travel_data.head(15)
# Out:
#                                                Agency    Agency Type  \
# 0                                                 CBH  Travel Agency
# 1                                                 CBH  Travel Agency
# 2                                                 CWT  Travel Agency
# 3                                                 CWT  Travel Agency
# 4                                                 CWT  Travel Agency
# 5                                                 JZI       Airlines
# 6                                                 CWT  Travel Agency
# 7                                                 CWT  Travel Agency
# 8                                                 CWT  Travel Agency
# 9                                                 CWT  Travel Agency
# 10  JZI,Airlines,Online,Basic Plan,No,33,"KOREA, D...            NaN
# 11                                                JZI       Airlines
# 12                                                KML  Travel Agency
# ...

# %% [markdown]
# En la linea 10 se identifica una inconsistencia en la lectura derevida del uso de comillas " " al inicio y al final de la fila, para evitarla, se reprocesa nuevamente el conjunto de datos. https://stackoverflow.com/questions/52517311/reading-a-csv-file-into-pandas-dataframe-with-quotation-in-some-entries

# %%
if not os.path.isfile('../data/new_travel_insurance.csv'):
    with open('../data/travel insurance.csv','r') as csv_file:
        for line in csv_file:
            # removing starting and ending quotes of a line
            pattern1 = re.compile(r'^"|"$',re.MULTILINE)
            line = re.sub(r'^"|"$',"",line)
            # substituting escaped quote with a single quote
            pattern2 = re.compile(r'""')
            line = re.sub(r'""','"',line)

            corrected_csv = open("../data/new_travel_insurance.csv",'a')
            corrected_csv.write(line)
            corrected_csv.close()

# %%
travel_raw = pd.read_csv('../data/new_travel_insurance.csv')

# %%
#Estandarizar nombre de las columnas a minusculas y reemplazar ' ' por '_'
travel_raw.columns = ['agency', 'agency_type', 'distribution_channel','product_name', 'claim',
                      'duration','destination','net_sales','commision', 'gender','age']

# %%
travel_raw.head(15)
# Out:
#    agency    agency_type distribution_channel  \
# 0     CBH  Travel Agency              Offline
# 1     CBH  Travel Agency              Offline
# 2     CWT  Travel Agency               Online
# 3     CWT  Travel Agency               Online
# 4     CWT  Travel Agency               Online
# 5     JZI       Airlines               Online
# 6     CWT  Travel Agency               Online
# 7     CWT  Travel Agency               Online
# 8     CWT  Travel Agency               Online
# 9     CWT  Travel Agency               Online
# 10    JZI       Airlines               Online
# 11    JZI       Airlines               Online
# 12    KML  Travel Agency               Online
# 13    CWT  Travel Agency               Online
# 14    EPX  Travel Agency               Online
#
#                        product_name claim  duration  \
# 0                Comprehensive Plan    No       186
# 1                Comprehensive Plan    No       186
# 2   Rental Vehicle Excess Insurance    No        65
# ...

# %% [markdown]
# # Análisis de los datos

# %% [markdown]
# ## Análisis estadístico básico

# %%
# Variables y tipos de datos
travel_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63326 entries, 0 to 63325
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   agency                63326 non-null  object
#  1   agency_type           63326 non-null  object
#  2   distribution_channel  63326 non-null  object
#  3   product_name          63326 non-null  object
#  4   claim                 63326 non-null  object
#  5   duration              63326 non-null  int64
#  6   destination           63326 non-null  object
#  7   net_sales             63326 non-null  float64
#  8   commision             63326 non-null  float64
#  9   gender                18219 non-null  object
#  10  age                   63326 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.3+ MB

# %%
#Forma, tamaño y número de valores del dataset

travel_raw.ndim
# Out:
# 2

# %%
travel_raw.shape
# Out:
# (63326, 11)

# %%
# Existencia de algun valor nulo en el set de datos
travel_raw.isnull().values.any()
# Out:
# True

# %%
#Total de valores nulos en cada variable
travel_raw.isnull().sum()
# Out:
# agency                      0
# agency_type                 0
# distribution_channel        0
# product_name                0
# claim                       0
# duration                    0
# destination                 0
# net_sales                   0
# commision                   0
# gender                  45107
# age                         0
# dtype: int64

# %%
#Resumen estadístico variables numéricas

travel_raw.describe()
# Out:
#            duration     net_sales     commision           age
# count  63326.000000  63326.000000  63326.000000  63326.000000
# mean      49.317074     40.702018      9.809992     39.969981
# std      101.791566     48.845637     19.804388     14.017010
# min       -2.000000   -389.000000      0.000000      0.000000
# 25%        9.000000     18.000000      0.000000     35.000000
# 50%       22.000000     26.530000      0.000000     36.000000
# 75%       53.000000     48.000000     11.550000     43.000000
# max     4881.000000    810.000000    283.500000    118.000000

# %%
# Definimos la función que nos dibujará los graficos de histograma y boxplot para las variables numéricas

#https://stackoverflow.com/questions/33381330/histogram-with-boxplot-above-in-python

def histogram_boxplot(data, xlabel = None, title = None, figsize=(10,8), bins = None):
    """ Boxplot and histogram combined
    data: 1-d data array
    xlabel: xlabel 
    title: title
    font_scale: the scale of the font (default 2)
    figsize: size of fig (default (9,8))
    bins: number of bins (default None / auto)

    example use: histogram_boxplot(np.random.rand(100), bins = 20, title="Fancy plot")
    """
    
    f2, (ax_box2, ax_hist2) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)}, figsize=figsize)
    sns.boxplot(data, ax=ax_box2)
    sns.distplot(data, ax=ax_hist2, bins=bins, kde=False) if bins else sns.distplot(data, ax=ax_hist2,kde=False)
    if xlabel: ax_hist2.set(xlabel=xlabel)
    if title: ax_box2.set(title=title)
    ax_box2.set(xlabel='')

    plt.show()

# %%
# Age
histogram_boxplot(travel_raw['age'], xlabel = "Age")

# %%
# Duration
histogram_boxplot(travel_raw['duration'], xlabel = "Duration")

# %%
# Net Sales
histogram_boxplot(travel_raw['net_sales'], xlabel = "Net Sales")

# %%
# Commision (in value)
histogram_boxplot(travel_raw['commision'], xlabel = "Commision")

# %% [markdown]
# **Observaciones:**
#
# + Se identifican valores negativos para las variables duration y net_sales
# + Valores outliers en variable age, 118 años y 0 años
# + Valor outliers en variable duration, 4881 y -2
# + El 50% de las observaciones no presenta valores superiores a 0 en la variable commision, podria ser una restricción no conocida sobre las ventas netas (net_sales)
#
# Analizar tratamiento de los mismos en sección de preparación y limpieza de los datos.

# %%
#Resumen estadístico variables categóricas


# Definimos la función que nos dibujará los graficos de barras para las variables categoricas con su frecuencia

#https://stackoverflow.com/questions/33179122/seaborn-countplot-with-frequencies

def plot_freq_catvar(var_cat, datos=None) -> None:
    
    dataplot = travel_raw if datos is None else datos

    #ncount = data[var_cat].notnull().sum()
    ncount = len(dataplot)

    plt.figure(figsize=(12,8))

    num_cat=len(dataplot[var_cat].value_counts().index)

    if num_cat > 10:
        ax = sns.countplot(x=var_cat,data=dataplot, order=dataplot[var_cat].value_counts().iloc[:10].index) 
    else:
        ax = sns.countplot(x=var_cat,data=dataplot, order=dataplot[var_cat].value_counts().index)

    ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')
    
    # Make twin axis
    ax2=ax.twinx()

    # Switch so count axis is on right, frequency on left
    ax2.yaxis.tick_left()
    ax.yaxis.tick_right()

    # Also switch the labels over
    ax.yaxis.set_label_position('right')
    ax2.yaxis.set_label_position('left')

    ax2.set_ylabel('Frequency [%]')

    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text

    # Use a LinearLocator to ensure the correct number of ticks
    ax.yaxis.set_major_locator(ticker.LinearLocator(11))

    # Fix the frequency range to 0-100
    ax2.set_ylim(0,100)
    ax.set_ylim(0,ncount+1000)

    # And use a MultipleLocator to ensure a tick spacing of 10
    ax2.yaxis.set_major_locator(ticker.MultipleLocator(10))

    # Need to turn the grid on ax2 off, otherwise the gridlines end up on top of the bars
    ax2.grid(None)
    
    plt.show()

# %%
# Claim
travel_raw['claim'].describe()
# Out:
# count     63326
# unique        2
# top          No
# freq      62399
# Name: claim, dtype: object

# %%
travel_raw.claim.value_counts()
# Out:
# No     62399
# Yes      927
# Name: claim, dtype: int64

# %%
plot_freq_catvar('claim')

# %%
#Agency
travel_raw.agency.describe()
# Out:
# count     63326
# unique       16
# top         EPX
# freq      35119
# Name: agency, dtype: object

# %%
travel_raw.agency.value_counts().iloc[:10]
# Out:
# EPX    35119
# CWT     8580
# C2B     8267
# JZI     6329
# SSI     1056
# JWT      749
# RAB      725
# LWC      689
# TST      528
# KML      392
# Name: agency, dtype: int64

# %%
plot_freq_catvar("agency")

# %%
#Agency Type
travel_raw["agency_type"].describe()
# Out:
# count             63326
# unique                2
# top       Travel Agency
# freq              45869
# Name: agency_type, dtype: object

# %%
travel_raw.agency_type.value_counts()
# Out:
# Travel Agency    45869
# Airlines         17457
# Name: agency_type, dtype: int64

# %%
plot_freq_catvar("agency_type")

# %%
# Distribution Channel
travel_raw["distribution_channel"].describe()
# Out:
# count      63326
# unique         2
# top       Online
# freq       62219
# Name: distribution_channel, dtype: object

# %%
travel_raw.distribution_channel.value_counts()
# Out:
# Online     62219
# Offline     1107
# Name: distribution_channel, dtype: int64

# %%
plot_freq_catvar("distribution_channel")

# %%
# Product Name
travel_raw["product_name"].describe()
# Out:
# count                 63326
# unique                   26
# top       Cancellation Plan
# freq                  18630
# Name: product_name, dtype: object

# %%
travel_raw.product_name.value_counts()
# Out:
# Cancellation Plan                       18630
# 2 way Comprehensive Plan                13158
# Rental Vehicle Excess Insurance          8580
# Basic Plan                               5469
# Bronze Plan                              4049
# 1 way Comprehensive Plan                 3331
# Value Plan                               2715
# Silver Plan                              2249
# Annual Silver Plan                       1423
# Ticket Protector                         1056
# Travel Cruise Protect                     527
# Comprehensive Plan                        364
# Gold Plan                                 352
# 24 Protect                                247
# Single Trip Travel Protect Gold           204
# Annual Gold Plan                          194
# Premier Plan                              194
# Single Trip Travel Protect Silver         173
# Annual Travel Protect Gold                100
# Annual Travel Protect Silver               86
# ...

# %%
plot_freq_catvar("product_name")

# %%
# Destination
travel_raw["destination"].describe()
# Out:
# count         63326
# unique          149
# top       SINGAPORE
# freq          13255
# Name: destination, dtype: object

# %%
travel_raw.destination.value_counts()
# Out:
# SINGAPORE                 13255
# MALAYSIA                   5930
# THAILAND                   5894
# CHINA                      4796
# AUSTRALIA                  3694
#                           ...
# SIERRA LEONE                  1
# GUATEMALA                     1
# TIBET                         1
# ARMENIA                       1
# REPUBLIC OF MONTENEGRO        1
# Name: destination, Length: 149, dtype: int64

# %%
plot_freq_catvar("destination")

# %%
# Gender
travel_raw["gender"].describe()
# Out:
# count     18219
# unique        2
# top           M
# freq       9347
# Name: gender, dtype: object

# %%
travel_raw.gender.value_counts()
# Out:
# M    9347
# F    8872
# Name: gender, dtype: int64

# %%
plot_freq_catvar("gender")

# %% [markdown]
# **Observaciones:**
#
# + Se identifican variables categóricas con cardinalidad media-alta:
#     + agency: 16 valores únicos
#     + product_name: 26 valores únicos
#     + destination: 149 valores únicos
#
#     Al momento de plantear el modelo es necesario considerar la tratamiento sobre estas variables categóricas, por ejemplo, una codificación tipo One Hot Encoding puede derivar en una gran cantidad de variables "dummy", más de 150, lo cual puede afectar la fase de entrenamiento y performance del modelo.
#
#
# + La variable gender cuenta con una cantidad elevada de valores NaN, más del 70% de las observaciones.
#
#
# + Se aprecia un desbalance considerable en la variable objetivo *claim*, mas del 95% de las observaciones corresponden al nivel No. Validar que método utilizar en la preparacion de los datos para desarrollar adecuadamente el modelo de clasificación objetivo.

# %% [markdown]
# ## Análisis exploratorio de los datos

# %% [markdown]
# En este apartado exploraremos la relación de algunos de los atributos con la variable respuesta ("claim"), tanto gráficamente como cuantitativamente, y analizaremos las diferentes correlaciones. Para empezar, seleccionaremos solo 5 atributos para explorar: age, duration , destination , distribution_channel y product name.

# %%
travel_claimed=travel_raw[travel_raw['claim']=='Yes']

# %%
ncount=len(travel_claimed)
plt.figure(figsize=(12,8))

ax=sns.countplot(x='product_name',data=travel_claimed, 
                 order=travel_claimed['product_name'].value_counts().iloc[:10].index)

ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text

plt.show()

# %%
plt.figure(figsize=(12,8))

ax=sns.countplot(x='destination',data=travel_claimed, 
                 order=travel_claimed['destination'].value_counts().iloc[:10].index)

ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text

plt.show()

# %%
plt.figure(figsize=(12,8))

claimed_singapore=travel_claimed[travel_claimed['destination']=="SINGAPORE"]
ncount=len(claimed_singapore)

ax=sns.countplot(x='product_name',data=claimed_singapore, 
                 order=claimed_singapore['product_name'].value_counts().iloc[:10].index)

ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text

plt.show()

# %%
index_product=travel_claimed.product_name.value_counts().iloc[:15].index
index_destination=travel_claimed.destination.value_counts().iloc[:15].index


travel_claimed_ct=travel_claimed[travel_claimed.product_name.isin(index_product) & travel_claimed.destination.isin(index_destination)]


pd.crosstab(travel_claimed_ct.product_name,  travel_claimed_ct.destination,margins=True, 
            margins_name="Total").sort_values(by = ['Total'], ascending = [False])
# Out:
# destination                      AUSTRALIA  CHINA  FRANCE  HONG KONG  \
# product_name
# Total                                   37     44       8         13
# Bronze Plan                              0      0       0          0
# Annual Silver Plan                       0      0       0          0
# Silver Plan                              0      0       0          0
# 2 way Comprehensive Plan                 5     29       1          8
# Rental Vehicle Excess Insurance         30      0       2          0
# Cancellation Plan                        0      3       3          2
# Annual Gold Plan                         0      0       0          0
# Basic Plan                               0      6       0          3
# Gold Plan                                0      0       0          0
# Value Plan                               1      1       0          0
# Annual Travel Protect Gold               0      3       0          0
# ...

# %%
plt.figure(figsize=(12,8))

travel_claimed_by_age=travel_claimed[travel_claimed.product_name.isin(index_product)]

ax=sns.boxplot(y='age',  x='product_name',
                 data=travel_claimed_by_age, 
                 palette="colorblind")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

plt.show()

# %%
plt.figure(figsize=(12,8))

travel_claimed_by_age=travel_claimed[travel_claimed.destination.isin(index_destination)]

ax=sns.boxplot(y='age',  x='destination',
                 data=travel_claimed_by_age, 
                 palette="colorblind")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

plt.show()

# %%
plt.figure(figsize=(12,8))

travel_claimed_by_dur=travel_claimed[travel_claimed.product_name.isin(index_product)]

ax=sns.boxplot(y='duration',  x='product_name',
                 data=travel_claimed_by_dur, 
                 palette="colorblind")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

plt.show()

# %%
plt.figure(figsize=(12,8))

travel_claimed_by_dur=travel_claimed[travel_claimed.destination.isin(index_destination)]

ax=sns.boxplot(y='duration',  x='destination',
                 data=travel_claimed_by_dur, 
                 palette="colorblind")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

plt.show()

# %%
ncount=len(travel_raw)

plt.figure(figsize=(12,8))
ax=sns.countplot(x='distribution_channel', data=travel_raw, hue='claim')

ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text
plt.show()

# %%
ncount=len(travel_raw)

plt.figure(figsize=(12,8))
ax=sns.countplot(x='agency_type', data=travel_raw, hue='claim')

ax.set_xticklabels(ax.get_xticklabels(),rotation=45, horizontalalignment='right')

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
                ha='center', va='bottom') # set the alignment of the text
plt.show()

# %% [markdown]
# # Preparación y Limpeza de los datos

# %%
travel_clean=travel_raw

# %% [markdown]
# + Variable distribution_channel
#
#     Del análisis exploratario es posible concluir que la variable distribution_channel no seria muy relevante para la construccion del modelo, más del 95% de las observaciones corresponden con el nivel Online y sobre este nivel se distingue una proporción baja de reclamaciones efectivas (Yes), por lo tanto no será considerada.

# %%
#Eliminar variable distribution_channel
travel_clean=travel_clean.drop('distribution_channel',1)
travel_clean.head(10)
# Out:
#   agency    agency_type                     product_name claim  duration  \
# 0    CBH  Travel Agency               Comprehensive Plan    No       186
# 1    CBH  Travel Agency               Comprehensive Plan    No       186
# 2    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        65
# 3    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        60
# 4    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        79
# 5    JZI       Airlines                       Value Plan    No        66
# 6    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        47
# 7    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        63
# 8    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        57
# 9    CWT  Travel Agency  Rental Vehicle Excess Insurance    No       186
#
#      destination  net_sales  commision gender  age
# 0       MALAYSIA      -29.0       9.57      F   81
# 1       MALAYSIA      -29.0       9.57      F   71
# ...

# %%
#Análisis de valores NaN en variable gender
ngender_na=travel_clean['gender'].isnull().sum()
ngender_na
# Out:
# 45107

# %%
ngender_na_pct=ngender_na/len(travel_raw)
print('Porcentaje de las muestras con valores NaN para la variable Gender = {:0.2f}%'.format(ngender_na_pct*100) )
# Out:
# Porcentaje de las muestras con valores NaN para la variable Gender = 71.23%

# %% [markdown]
# Como el porcentaje de valores nulos sobre esta variable es bastante alto no se considerará para la construcción del modelo.

# %%
#Eliminar variable Gender
travel_clean=travel_clean.drop('gender',1)
travel_clean.head(10)
# Out:
#   agency    agency_type                     product_name claim  duration  \
# 0    CBH  Travel Agency               Comprehensive Plan    No       186
# 1    CBH  Travel Agency               Comprehensive Plan    No       186
# 2    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        65
# 3    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        60
# 4    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        79
# 5    JZI       Airlines                       Value Plan    No        66
# 6    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        47
# 7    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        63
# 8    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        57
# 9    CWT  Travel Agency  Rental Vehicle Excess Insurance    No       186
#
#      destination  net_sales  commision  age
# 0       MALAYSIA      -29.0       9.57   81
# 1       MALAYSIA      -29.0       9.57   71
# ...

# %%
#Eliminar observaciones que presentan valores negativos o iguales a cero en Net Sales
travel_clean[travel_clean["net_sales"] <= 0]
# Out:
#       agency    agency_type                     product_name claim  duration  \
# 0        CBH  Travel Agency               Comprehensive Plan    No       186
# 1        CBH  Travel Agency               Comprehensive Plan    No       186
# 2        CWT  Travel Agency  Rental Vehicle Excess Insurance    No        65
# 3        CWT  Travel Agency  Rental Vehicle Excess Insurance    No        60
# 4        CWT  Travel Agency  Rental Vehicle Excess Insurance    No        79
# ...      ...            ...                              ...   ...       ...
# 62806    C2B       Airlines                      Bronze Plan    No        12
# 62833    CWT  Travel Agency  Rental Vehicle Excess Insurance    No       165
# 62993    CWT  Travel Agency  Rental Vehicle Excess Insurance    No         5
# 62996    CWT  Travel Agency  Rental Vehicle Excess Insurance    No         3
# 63001    CWT  Travel Agency  Rental Vehicle Excess Insurance    No        13
#
#       destination  net_sales  commision  age
# ...

# %%
travel_clean=travel_clean[travel_clean["net_sales"] > 0]

# %%
#Analizar outliers en variable Duration
travel_clean[travel_clean["duration"] >1000]
# Out:
#       agency agency_type      product_name claim  duration destination  \
# 3025     SSI    Airlines  Ticket Protector    No      4881   SINGAPORE
# 6847     SSI    Airlines  Ticket Protector    No      4857   SINGAPORE
# 8686     SSI    Airlines  Ticket Protector    No      4847   SINGAPORE
# 9232     SSI    Airlines  Ticket Protector    No      4844   SINGAPORE
# 12059    SSI    Airlines  Ticket Protector    No      4831   SINGAPORE
# 12438    SSI    Airlines  Ticket Protector    No      4829   SINGAPORE
# 15281    SSI    Airlines  Ticket Protector    No      4815   SINGAPORE
# 21916    SSI    Airlines  Ticket Protector    No      4784   SINGAPORE
# 30437    SSI    Airlines  Ticket Protector    No      4738   SINGAPORE
# 30826    SSI    Airlines  Ticket Protector    No      4736   SINGAPORE
# 39842    SSI    Airlines  Ticket Protector    No      4685   SINGAPORE
# 41391    SSI    Airlines  Ticket Protector    No      4652   SINGAPORE
# ...

# %%
#Eliminar este conjunto de valores outliers en variable Duration, no presentan reclamaciones efectivas (Yes), 
#son pocas observaciones y muy similares entre si
travel_clean=travel_clean[travel_clean["duration"] < 1000]

# %%
#Análisis de valores negativos o iguales a 0 en variable Duration
travel_clean[travel_clean['duration'] <= 0]
# Out:
#       agency agency_type      product_name claim  duration        destination  \
# 911      RAB    Airlines        Value Plan    No         0  BRUNEI DARUSSALAM
# 2515     JZI    Airlines        Basic Plan    No         0            MYANMAR
# 2868     JZI    Airlines        Basic Plan    No         0          INDONESIA
# 3282     RAB    Airlines        Value Plan    No         0  BRUNEI DARUSSALAM
# 3577     SSI    Airlines  Ticket Protector    No         0          SINGAPORE
# ...      ...         ...               ...   ...       ...                ...
# 57114    RAB    Airlines        Value Plan    No         0  BRUNEI DARUSSALAM
# 59528    JZI    Airlines        Basic Plan    No        -1              CHINA
# 60746    SSI    Airlines  Ticket Protector    No         0          SINGAPORE
# 63097    C2B    Airlines       Bronze Plan    No         0          SINGAPORE
# 63307    SSI    Airlines  Ticket Protector    No         0          SINGAPORE
#
#        net_sales  commision  age
# ...

# %%
# Los valores en Duration menores o iguales a cero se imputaran con el promedio de duration de acuerdo al destino
destinations = travel_clean[travel_clean['duration'] <= 0].destination
mean_duration_by_dest=(travel_clean[travel_clean.destination.isin(destinations)]).groupby('destination')['duration'].mean()

mean_duration_by_dest
# Out:
# destination
# BANGLADESH           13.460000
# BRUNEI DARUSSALAM    23.565670
# CHINA                35.174973
# INDIA                32.036718
# INDONESIA            31.521073
# MALAYSIA             26.534290
# MYANMAR              32.117276
# SINGAPORE            74.385970
# THAILAND             32.927812
# UNITED STATES        74.792500
# VIET NAM             25.048141
# Name: duration, dtype: float64

# %%
#Imputar valores en Duration menores o iguales a cero con mean_duration_by_dest
for key in mean_duration_by_dest.index.values:
    travel_clean.loc[travel_clean['duration'] <= 0 & (travel_clean['destination']==key) , 'duration']=mean_duration_by_dest[key]

# %%
#Analizar outliers en variable Age
travel_clean[(travel_clean["age"]) > 100 ]
# Out:
#       agency    agency_type        product_name claim  duration destination  \
# 105      JWT       Airlines          Value Plan    No      11.0       INDIA
# 220      JWT       Airlines          Value Plan    No       4.0       INDIA
# 367      JWT       Airlines          Value Plan    No      16.0       INDIA
# 402      CCR  Travel Agency  Comprehensive Plan    No       5.0    MALAYSIA
# 403      CCR  Travel Agency  Comprehensive Plan    No       5.0    MALAYSIA
# ...      ...            ...                 ...   ...       ...         ...
# 62920    JWT       Airlines          Value Plan    No       2.0       INDIA
# 62953    ART       Airlines          Value Plan    No      14.0      FRANCE
# 63096    ART       Airlines          Value Plan    No      42.0   HONG KONG
# 63182    JWT       Airlines          Value Plan    No      21.0       INDIA
# 63183    JWT       Airlines          Value Plan    No      49.0       INDIA
#
#        net_sales  commision  age
# ...

# %%
#Analizar outliers en variable Age
travel_clean[(travel_clean["age"]) == 0 ]
# Out:
#       agency    agency_type           product_name claim  duration  \
# 41993    TST  Travel Agency  Travel Cruise Protect    No      94.0
#
#       destination  net_sales  commision  age
# 41993    THAILAND       30.0       10.5    0

# %%
#Para las edades supueriores a 100 años o iguales a cero, se imputaran valores con la mediana de la variable Age

age_median=np.median(travel_clean['age'])
travel_clean.loc[travel_clean["age"] >100,'age'] = age_median
travel_clean.loc[travel_clean["age"] == 0,'age'] = age_median

# %%
travel_clean.describe()
# Out:
#            duration     net_sales     commision           age
# count  60750.000000  60750.000000  60750.000000  60750.000000
# mean      47.869637     43.108144      9.347845     38.696379
# std       73.710603     47.787150     19.471318      9.994580
# min        1.000000      0.070000      0.000000      1.000000
# 25%        9.000000     19.800000      0.000000     35.000000
# 50%       22.000000     28.000000      0.000000     36.000000
# 75%       52.000000     49.500000     10.500000     42.000000
# max      547.000000    810.000000    283.500000     88.000000

# %%
# Cambiar tipo de dato a category para las variables categóricas
# category	Finite list of text values

cols_to_exclude = ['age', 'duration', 'net_sales', 'commision']
for col in travel_clean.columns:
    if travel_clean[col].nunique() < 200 and col not in cols_to_exclude:
        travel_clean[col] = travel_clean[col].astype('category')

# %%
travel_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60750 entries, 21 to 63325
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   agency        60750 non-null  category
#  1   agency_type   60750 non-null  category
#  2   product_name  60750 non-null  category
#  3   claim         60750 non-null  category
#  4   duration      60750 non-null  float64
#  5   destination   60750 non-null  category
#  6   net_sales     60750 non-null  float64
#  7   commision     60750 non-null  float64
#  8   age           60750 non-null  float64
# dtypes: category(5), float64(4)
# memory usage: 2.7 MB

# %%
travel_clean.head(10)
# Out:
#    agency    agency_type                     product_name claim  duration  \
# 21    C2B       Airlines                      Bronze Plan    No      12.0
# 22    C2B       Airlines                      Bronze Plan    No       7.0
# 23    C2B       Airlines                      Bronze Plan   Yes      12.0
# 24    C2B       Airlines                      Silver Plan    No     190.0
# 25    C2B       Airlines               Annual Silver Plan    No     364.0
# 26    CWT  Travel Agency  Rental Vehicle Excess Insurance    No      29.0
# 27    CWT  Travel Agency  Rental Vehicle Excess Insurance    No      28.0
# 28    CWT  Travel Agency  Rental Vehicle Excess Insurance    No     153.0
# 29    CWT  Travel Agency  Rental Vehicle Excess Insurance    No      28.0
# 30    CWT  Travel Agency  Rental Vehicle Excess Insurance    No       4.0
#
#        destination  net_sales  commision   age
# 21       SINGAPORE      46.15      11.54  44.0
# 22       SINGAPORE      17.55       4.39  25.0
# ...

# %%
# One hot encoding y lower case variables categoticas predictoras
columns=['agency','agency_type','product_name','destination']

for column in columns:
    travel_clean[column]=travel_clean[column].str.lower()
    one_hot = pd.get_dummies(travel_clean[column])
    # Drop first column in one_hot
    one_hot=one_hot.drop(one_hot.columns[[0]], axis=1)
    # Drop column as it is now encoded
    travel_clean = travel_clean.drop(column,axis = 1)
    # Join the encoded df
    travel_clean = travel_clean.join(one_hot)

# %%
# Label encoding en target: claim
le = preprocessing.LabelEncoder()
travel_clean['claim_label'] = le.fit_transform(travel_clean.claim.values)

travel_clean = travel_clean.drop('claim',axis = 1)

# %%
# Estandarización en variables numéricas predictoras
from sklearn.preprocessing import StandardScaler

#columns=['duration','net_sales','commision','age','art']
columns=travel_clean.columns[travel_clean.columns != 'claim_label']
scaler = StandardScaler()
travel_clean[columns]=scaler.fit_transform(travel_clean[columns])

# %%
travel_clean.columns = travel_clean.columns.str.replace(' ','_')
travel_clean.columns = travel_clean.columns.str.replace(',','')

travel_clean.reset_index(drop=True,inplace=True)

# %%
travel_clean.head(10)
# Out:
#    duration  net_sales  commision       age       art       c2b       cbh  \
# 0 -0.486632   0.063655   0.112585  0.530654 -0.072311  2.553148 -0.039367
# 1 -0.554465  -0.534837  -0.254625 -1.370392 -0.072311  2.553148 -0.039367
# 2 -0.486632   1.064978   0.726827 -0.469896 -0.072311  2.553148 -0.039367
# 3  1.928237   5.265933   3.304485 -1.270337 -0.072311  2.553148 -0.039367
# 4  4.288840   7.238237   4.514480 -0.870117 -0.072311  2.553148 -0.039367
# 5 -0.255998  -0.694924  -0.175020 -0.569951 -0.072311 -0.391673 -0.039367
# 6 -0.269565  -0.694924  -0.175020 -0.569951 -0.072311 -0.391673 -0.039367
# 7  1.426270   0.548099   1.655379 -0.369841 -0.072311 -0.391673 -0.039367
# 8 -0.269565  -0.487753   0.130046 -0.770062 -0.072311 -0.391673 -0.039367
# 9 -0.595165  -0.280583   0.435113  2.231590 -0.072311 -0.391673 -0.039367
#
#         ccr       csr       cwt       epx       jwt       jzi       kml  \
# 0 -0.056012 -0.037652 -0.367257 -1.141897 -0.111046 -0.336373 -0.080174
# ...

# %%
travel_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60750 entries, 0 to 60749
# Columns: 191 entries, duration to claim_label
# dtypes: float64(190), int64(1)
# memory usage: 88.5 MB

# %%
travel_clean.claim_label.value_counts()
# Out:
# 0    59826
# 1      924
# Name: claim_label, dtype: int64

# %% [markdown]
# # Selección de Variables

# %% [markdown]
# Antes de aplicar algún modelo, tenemos que separar los datos entre los conjuntos de train y test. Siempre trabajaremos sobre el conjunto de train y evaluaremos los resultados en el conjunto de test.

# %% [markdown]
# ## Train y test data

# %%
X = travel_clean.loc[ : , travel_clean.columns != 'claim_label'].values 
y = travel_clean['claim_label'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## ANOVA

# %%
# ANOVA feature selection for numeric input and categorical output

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from matplotlib import pyplot

feature_names=travel_clean.columns[travel_clean.columns != 'claim_label']

# define feature selection
fs = SelectKBest(score_func=f_classif, k='all')

# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)

x= []
# what are scores for the features
for i in range(len(fs.scores_)):
    x.append([i,feature_names[i], fs.scores_[i]])
    
sorted(x,key=lambda x:x[2], reverse=True)
# Out:
# [[5, 'c2b', 1154.5934962719784],
#  [1, 'net_sales', 726.6307804587351],
#  [23, 'annual_silver_plan', 676.2194789086017],
#  [159, 'singapore', 560.3903131296539],
#  [0, 'duration', 465.4692914028683],
#  [2, 'commision', 444.3414733006464],
#  [19, 'travel_agency', 379.7412583079656],
#  [10, 'epx', 302.0121861702853],
#  [28, 'bronze_plan', 259.3591921438846],
#  [36, 'silver_plan', 226.24063733140153],
#  [29, 'cancellation_plan', 182.55770490989823],
#  [22, 'annual_gold_plan', 45.32721858724686],
#  [120, 'malaysia', 40.68931412750801],
#  [12, 'jzi', 35.732838172581644],
#  [27, 'basic_plan', 31.18800137010424],
#  [14, 'lwc', 27.59772986167189],
#  [32, 'gold_plan', 26.502370098809642],
#  [24, 'annual_travel_protect_gold', 25.79758774083218],
#  [99, 'indonesia', 24.240242105829754],
#  [170, 'thailand', 18.908656351393244],
#  [143, 'philippines', 15.172094622816962],
#  [70, 'costa_rica', 14.702932205445517],
#  [98, 'india', 12.934962790786187],
# ...

# %%
# plot the scores
pyplot.figure(figsize=(20,10))
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()

# %% [markdown]
# ## Boruta

# %%
#conda install -c conda-forge boruta_py
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy as bp

feature_names=travel_clean.columns[travel_clean.columns != 'claim_label']

rf_model = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5, random_state=42)
feat_selector = bp(rf_model,n_estimators = 'auto', verbose= 0,max_iter= 100,random_state=42)
feat_selector.fit(X_train, y_train)

selected_features = [feature_names[i] for i, x in enumerate(feat_selector.support_) if x]
print(selected_features)
# Out:
# ['duration', 'net_sales', 'commision', 'age', 'c2b', 'epx', 'jzi', 'travel_agency', '2_way_comprehensive_plan', 'annual_silver_plan', 'bronze_plan', 'cancellation_plan', 'singapore']

# %%
X_train_bp = feat_selector.transform(X_train)
X_test_bp = feat_selector.transform(X_test)

# %%
# define feature selection ANOVA top 13
fs = SelectKBest(score_func=f_classif, k=13)

# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)

# %%
feature_names=travel_clean.columns[travel_clean.columns != 'claim_label']
selected_features = [feature_names[i] for i in fs.get_support(indices=True) ]
print(selected_features)
# Out:
# ['duration', 'net_sales', 'commision', 'c2b', 'epx', 'travel_agency', 'annual_gold_plan', 'annual_silver_plan', 'bronze_plan', 'cancellation_plan', 'silver_plan', 'malaysia', 'singapore']

# %% [markdown]
# ## Reducción de la dimensionalidad (PCA)

# %%
from sklearn.decomposition import PCA

pca=PCA()
X_filtered_pca=pca.fit_transform(X_train)

# %%
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(12,8))
plt.plot(exp_var_cumul)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
pca=PCA()
X_train_bp_pca=pca.fit_transform(X_train_bp)

# %%
exp_var_cumul = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(12,8))
plt.plot(exp_var_cumul)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
pca=PCA(6)
X_train_bp_pca=pca.fit_transform(X_train_bp)
X_test_bp_pca=pca.fit_transform(X_test_bp)

# %% [markdown]
# # Aplicación de modelos

# %% [markdown]
# ## Resample sobre Train data

# %% [markdown]
# ### SMOTE - Random Undersample

# %%
# Oversample with SMOTE and random undersample for imbalanced dataset

from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# summarize class distribution
counter = Counter(y)
print(counter)
# define pipeline
over = SMOTE(sampling_strategy=0.05, random_state=42)
under = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
steps = [('o', over), ('u', under)]
pipeline = Pipeline(steps=steps)
# transform the dataset
X_sm, y_sm = pipeline.fit_resample(X_train_bp, y_train)
X_sm_pca, y_sm_pca = pipeline.fit_resample(X_train_bp_pca, y_train)
# summarize the new class distribution
counter = Counter(y_sm)
print(counter)
# Out:
# Counter({0: 59826, 1: 924})
# Counter({0: 4008, 1: 2004})

# %% [markdown]
# ### SMOTETomek

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks


counter = Counter(y)
print(counter)

# define sampling strategy
resample = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'),random_state=42)
# define pipeline
pipeline = Pipeline(steps=[('r', resample)])

# transform the dataset
X_smt, y_smt = pipeline.fit_resample(X_train_bp, y_train)
X_smt_pca, y_smt_pca = pipeline.fit_resample(X_train_bp_pca, y_train)
# summarize the new class distribution
counter = Counter(y_smt)
print(counter)
# Out:
# Counter({0: 59826, 1: 924})
# Counter({1: 40082, 0: 39366})

# %% [markdown]
# ## Regresión Logística

# %%
from sklearn.linear_model import LogisticRegression


#Boruta + SMOTE-RU

# define model
model = LogisticRegression()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.820

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print(classification_report(y_test, predictions, labels=[0, 1], target_names=['NO','YES']))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.99      0.87      0.93     19744
#          YES       0.07      0.63      0.12       304
#
#     accuracy                           0.86     20048
#    macro avg       0.53      0.75      0.52     20048
# weighted avg       0.98      0.86      0.91     20048

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.864
# AUC ROC Score = 0.825
# AUC PR Score = 0.081
# Kappa Score = 0.099
# F1 Score = 0.124
# Recall Score = 0.632
# Precision Score = 0.068

# %%
from sklearn.linear_model import LogisticRegression

#Boruta + PCA + SMOTE-RU

# define model
model = LogisticRegression()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm_pca, y_sm_pca, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.812

# %%
model.fit(X_sm_pca, y_sm_pca)
predictions=model.predict(X_test_bp_pca)

pred_proba=model.predict_proba(X_test_bp_pca)

prob_y_1 = [p[1] for p in pred_proba]

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp_pca, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print(classification_report(y_test, predictions, labels=[0, 1], target_names=['NO','YES']))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.99      0.89      0.94     19744
#          YES       0.07      0.51      0.12       304
#
#     accuracy                           0.89     20048
#    macro avg       0.53      0.70      0.53     20048
# weighted avg       0.98      0.89      0.93     20048

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.887
# AUC ROC Score = 0.822
# AUC PR Score = 0.078
# Kappa Score = 0.097
# F1 Score = 0.121
# Recall Score = 0.513
# Precision Score = 0.068

# %%
from sklearn.linear_model import LogisticRegression

#Boruta + SMOTE Tomemek

# define model
model = LogisticRegression()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_smt, y_smt, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.823

# %%
model.fit(X_smt, y_smt)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print(classification_report(y_test, predictions, labels=[0, 1], target_names=['NO','YES']))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.99      0.81      0.89     19744
#          YES       0.05      0.70      0.10       304
#
#     accuracy                           0.80     20048
#    macro avg       0.52      0.75      0.49     20048
# weighted avg       0.98      0.80      0.88     20048

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.804
# AUC ROC Score = 0.827
# AUC PR Score = 0.082
# Kappa Score = 0.072
# F1 Score = 0.098
# Recall Score = 0.704
# Precision Score = 0.053

# %%
from sklearn.linear_model import LogisticRegression

#Boruta + PCA + SMOTE-Tomemek

# define model
model = LogisticRegression()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_smt_pca, y_smt_pca, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.814

# %%
model.fit(X_smt_pca, y_smt_pca)
predictions=model.predict(X_test_bp_pca)

pred_proba=model.predict_proba(X_test_bp_pca)

prob_y_1 = [p[1] for p in pred_proba]

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp_pca, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print(classification_report(y_test, predictions, labels=[0, 1], target_names=['NO','YES']))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.99      0.81      0.89     19744
#          YES       0.05      0.71      0.10       304
#
#     accuracy                           0.81     20048
#    macro avg       0.52      0.76      0.50     20048
# weighted avg       0.98      0.81      0.88     20048

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.808
# AUC ROC Score = 0.825
# AUC PR Score = 0.077
# Kappa Score = 0.074
# F1 Score = 0.101
# Recall Score = 0.707
# Precision Score = 0.054

# %% [markdown]
# ### Optimización del modelo

# %%
## GridSearch

from sklearn.model_selection import GridSearchCV

model = LogisticRegression()

# define the grid of values to search
grid = dict()
grid['C'] = [100, 50, 10, 1 , 0.1, 0.001, 0.0001]
grid['solver']=['lbfgs','saga','liblinear','newton-cg']
grid['penalty']=['l1', 'l2', 'elasticnet'] 


# define the evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# define the grid search procedure
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='roc_auc')

# execute the grid search
grid_result = grid_search.fit(X_sm, y_sm)

# summarize the best score and configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.820266 using {'C': 1, 'penalty': 'l1', 'solver': 'saga'}

# %%
from sklearn.linear_model import LogisticRegression

# define model
model = LogisticRegression(C=1, penalty= 'l1', solver= 'saga')
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.820

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print(classification_report(y_test, predictions, labels=[0, 1], target_names=['NO','YES']))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.99      0.87      0.93     19744
#          YES       0.07      0.63      0.12       304
#
#     accuracy                           0.86     20048
#    macro avg       0.53      0.75      0.52     20048
# weighted avg       0.98      0.86      0.91     20048

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.864
# AUC ROC Score = 0.825
# AUC PR Score = 0.081
# Kappa Score = 0.099
# F1 Score = 0.123
# Recall Score = 0.632
# Precision Score = 0.068

# %% [markdown]
# ## Combinación paralela de clasificadores

# %% [markdown]
# https://machinelearningmastery.com/bagging-and-random-forest-for-imbalanced-classification/
#
# https://anaconda.org/conda-forge/imbalanced-learn
#
# https://imbalanced-learn.readthedocs.io/en/stable/api.html
#
# conda install -c conda-forge imbalanced-learn

# %% [markdown]
# ###  Bagging

# %%
# bagged decision trees on an imbalanced classification problem
from sklearn.ensemble import BaggingClassifier
# define model
model = BaggingClassifier(n_estimators= 200)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.916

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.881
# AUC ROC Score = 0.774
# AUC PR Score = 0.060
# Kappa Score = 0.078
# F1 Score = 0.103
# Recall Score = 0.451
# Precision Score = 0.058

# %%
# bagged decision trees with random undersampling for imbalanced classification
from imblearn.ensemble import BalancedBaggingClassifier

# define model
model = BalancedBaggingClassifier(n_estimators= 200)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_train_bp, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.800

# %%
model.fit(X_train_bp, y_train)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.806
# AUC ROC Score = 0.798
# AUC PR Score = 0.066
# Kappa Score = 0.066
# F1 Score = 0.092
# Recall Score = 0.648
# Precision Score = 0.050

# %% [markdown]
# ### Random Forest

# %%
# random forest for imbalanced classification
from sklearn.ensemble import RandomForestClassifier

# define model
model = RandomForestClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.918

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.880
# AUC ROC Score = 0.772
# AUC PR Score = 0.063
# Kappa Score = 0.071
# F1 Score = 0.096
# Recall Score = 0.418
# Precision Score = 0.054

# %%
# class balanced random forest for imbalanced classification
from sklearn.ensemble import RandomForestClassifier

# define model
model = RandomForestClassifier(class_weight='balanced')
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_train_bp, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.680

# %%
model.fit(X_train_bp, y_train)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.977
# AUC ROC Score = 0.685
# AUC PR Score = 0.045
# Kappa Score = 0.030
# F1 Score = 0.041
# Recall Score = 0.033
# Precision Score = 0.053

# %%
# random forest with random undersampling for imbalanced classification
from imblearn.ensemble import BalancedRandomForestClassifier

# define model
model = BalancedRandomForestClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_train_bp, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.803

# %%
model.fit(X_train_bp, y_train)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.724
# AUC ROC Score = 0.808
# AUC PR Score = 0.069
# Kappa Score = 0.048
# F1 Score = 0.076
# Recall Score = 0.743
# Precision Score = 0.040

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# define model
model = GradientBoostingClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.871

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.892
# AUC ROC Score = 0.819
# AUC PR Score = 0.074
# Kappa Score = 0.106
# F1 Score = 0.130
# Recall Score = 0.533
# Precision Score = 0.074

# %% [markdown]
# ### Extreme Gradient Boosting

# %%
# fit balanced xgboost on an imbalanced classification dataset,  pip install xgboost==0.90
#https://machinelearningmastery.com/xgboost-for-imbalanced-classification/
from xgboost import XGBClassifier

# count examples in each class
counter = Counter(y_train)
# estimate scale_pos_weight value
estimate = counter[0] / counter[1]
print('Estimate: %.3f' % estimate)
# define model
model = XGBClassifier(scale_pos_weight=estimate, eval_metric='auc')
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_train_bp, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Estimate: 64.648
# Mean ROC AUC: 0.734

# %%
model.fit(X_train_bp, y_train)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.904
# AUC ROC Score = 0.711
# AUC PR Score = 0.050
# Kappa Score = 0.070
# F1 Score = 0.094
# Recall Score = 0.329
# Precision Score = 0.055

# %%
## Train data con resample

# fit balanced xgboost on an imbalanced classification dataset, pip3 install xgboost
#https://machinelearningmastery.com/xgboost-for-imbalanced-classification/
from xgboost import XGBClassifier


# count examples in each class
counter = Counter(y_sm)
# estimate scale_pos_weight value
estimate = counter[0] / counter[1]
print('Estimate: %.3f' % estimate)
# define model
model = XGBClassifier(scale_pos_weight=estimate, eval_metric='auc')
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Estimate: 2.000
# Mean ROC AUC: 0.923

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.871
# AUC ROC Score = 0.778
# AUC PR Score = 0.066
# Kappa Score = 0.077
# F1 Score = 0.102
# Recall Score = 0.484
# Precision Score = 0.057

# %% [markdown]
# ### Easy Ensemble (combines bagging and boosting)

# %%
# easy ensemble for imbalanced classification
from imblearn.ensemble import EasyEnsembleClassifier

# define model
model = EasyEnsembleClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_train_bp, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.804

# %%
model.fit(X_train_bp, y_train)
predictions=model.predict(X_test_bp)


pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.768
# AUC ROC Score = 0.815
# AUC PR Score = 0.063
# Kappa Score = 0.059
# F1 Score = 0.085
# Recall Score = 0.714
# Precision Score = 0.045

# %% [markdown]
# ## Combinación secuencial de clasificadores base diferentes

# %% [markdown]
# ###  Arbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier

dtc_model = DecisionTreeClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(dtc_model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.792

# %%
dtc_model.fit(X_sm, y_sm)
predictions=dtc_model.predict(X_test_bp)


pred_proba=dtc_model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(dtc_model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.845
# AUC ROC Score = 0.639
# AUC PR Score = 0.236
# Kappa Score = 0.050
# F1 Score = 0.076
# Recall Score = 0.421
# Precision Score = 0.042

# %% [markdown]
# ### SVM

# %%
from sklearn import svm

svm_model = svm.SVC(probability=True)

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(svm_model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.785

# %%
svm_model.fit(X_sm, y_sm)
predictions=svm_model.predict(X_test_bp)


pred_proba=svm_model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(svm_model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.865
# AUC ROC Score = 0.778
# AUC PR Score = 0.064
# Kappa Score = 0.099
# F1 Score = 0.123
# Recall Score = 0.628
# Precision Score = 0.068

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Crear modelo base
knn_model = KNeighborsClassifier()

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(knn_model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.885

# %%
knn_model.fit(X_sm, y_sm)
predictions=knn_model.predict(X_test_bp)


pred_proba=knn_model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(knn_model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.830
# AUC ROC Score = 0.739
# AUC PR Score = 0.137
# Kappa Score = 0.062
# F1 Score = 0.088
# Recall Score = 0.543
# Precision Score = 0.048

# %% [markdown]
# ### Stacking

# %%
from sklearn.ensemble import StackingClassifier

# Create Base Learners
base_learners = [
                 ('rf_1', DecisionTreeClassifier()),
                 ('rf_2', svm.SVC(probability=True)),
                 ('rf_3', KNeighborsClassifier())             
                ]
                  
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# Initialize Stacking Classifier with the Meta Learner
clf = StackingClassifier(estimators=base_learners, final_estimator=LogisticRegression())

scores = cross_val_score(clf, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))
# Out:
# Mean ROC AUC: 0.900

# %%
# Extract score
clf.fit(X_sm, y_sm)
predictions=clf.predict(X_test_bp)

pred_proba=clf.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(clf, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")


plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
# Out:
# Accuray Score = 0.882
# AUC ROC Score = 0.769
# AUC PR Score = 0.057
# Kappa Score = 0.085
# F1 Score = 0.109
# Recall Score = 0.477
# Precision Score = 0.062

# %% [markdown]
# ## AutoML

# %% [markdown]
# ### Modelo AutoML 1: Tree-based Pipeline Optimization Tool (TPOT)

# %%
# example of tpot for a classification dataset, la ejecución puede tomar un par de horas
# conda install -c conda-forge tpot
from tpot import TPOTClassifier

# define model evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# define search
model = TPOTClassifier(generations=5, population_size=50, cv=cv, scoring='roc_auc', verbosity=2, random_state=42, n_jobs=-1)

# perform the search
model.fit(X_train, y_train)

# export the best model
model.export('tpot_best_model.py')

# %% [markdown]
# #### Evaluación del modelo

# %%
#Ejemplo de referencia

from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import FastICA
from tpot.export_utils import set_param_recursive
from sklearn.pipeline import make_pipeline

exported_pipeline = make_pipeline(
    FastICA(tol=0.8500000000000001),
    MLPClassifier(alpha=0.0001, learning_rate_init=0.01)
)
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 42)


cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
scores = cross_val_score(exported_pipeline, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))

# %%
exported_pipeline.fit(X_train, y_train)
predictions=exported_pipeline.predict(X_test)

pred_proba=exported_pipeline.predict_proba(X_test)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(exported_pipeline, X_test, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")


plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))

# %% [markdown]
# #### Evaluación del modelo con resample

# %%
# con SMOTE + RU, la ejecución puede tomar un par de horas
from tpot import TPOTClassifier

# define model evaluation
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# define search
model = TPOTClassifier(generations=5, population_size=50, cv=cv, scoring='roc_auc', verbosity=2, random_state=42, n_jobs=-1)

# perform the search
model.fit(X_sm, y_sm)

# export the best model
model.export('tpot_best_model_sm.py')

# %%
from sklearn.ensemble import GradientBoostingClassifier

# define model
model = GradientBoostingClassifier(learning_rate=0.1, max_depth=10, max_features=0.9500000000000001, min_samples_leaf=7, min_samples_split=20, n_estimators=100, subsample=0.8500000000000001)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))

# %%
model.fit(X_sm, y_sm)
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")


plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))

# %% [markdown]
# ### Modelo AutoML 2: Hyperopt-Sklearn

# %%
# pip install hyperopt , pip install git+https://github.com/hyperopt/hyperopt-sklearn.git

# example of hyperopt-sklearn for a classification dataset
from hpsklearn import HyperoptEstimator
from hpsklearn import any_classifier
from hpsklearn import any_preprocessing
from hyperopt import tpe

# define search
model = HyperoptEstimator(classifier=any_classifier('cla'), preprocessing=any_preprocessing('pre'), algo=tpe.suggest, max_evals=20, trial_timeout=30)

# perform the search
model.fit(X_train, y_train)


# summarize the best model
print(model.best_model())

# %% [markdown]
# #### Evaluación del modelo

# %%
#Modelo de referencia
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier(bootstrap=True,criterion='entropy', max_depth=3, 
                             max_features='log2', n_estimators=260, n_jobs=1,
                             random_state=42, verbose=False)

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))

# %%
model.fit(X_train, y_train)

predictions=model.predict(X_test)

pred_proba=model.predict_proba(X_test)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))

# %% [markdown]
# #### Evaluación del modelo con resample

# %%
# con SMOTE + RU


# define search
model = HyperoptEstimator(classifier=any_classifier('cla'), preprocessing=any_preprocessing('pre'), algo=tpe.suggest, max_evals=20, trial_timeout=30)

# perform the search
model.fit(X_sm, y_sm)


# summarize the best model
print(model.best_model())

# %%
#Modelo de referencia

model = KNeighborsClassifier(n_jobs=1, n_neighbors=1, p=4.0, weights='distance')

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)

# evaluate model
scores = cross_val_score(model, X_sm, y_sm, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: {:0.3f}'.format(mean(scores)))

# %%
model.fit(X_sm, y_sm)

predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

accuracy = accuracy_score(y_test, predictions)

f, ax = plt.subplots(figsize =(10, 8))
plot_confusion_matrix(model, X_test_bp, y_test,
                           display_labels=['No', 'Yes'],
                                 cmap=plt.cm.Blues, ax = ax )

plt.grid(False)
plt.title("Matriz de Confusión")

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC ROC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('AUC PR Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))

# %% [markdown]
# ### Modelo AutoML 3: Auto-Sklearn

# %%
# https://machinelearningmastery.com/auto-sklearn-for-automated-machine-learning-in-python/

from autosklearn.classification import AutoSklearnClassifier
from autosklearn.metrics import roc_auc


# define search
model = AutoSklearnClassifier(time_left_for_this_task=5*60, per_run_time_limit=30, n_jobs=8, metric=roc_auc)

# perform the search
model.fit(X_train, y_train)

# summarize
print(model.sprint_statistics())

# %% [markdown]
# #### Evaluación del modelo

# %%
predictions=model.predict(X_test)

pred_proba=model.predict_proba(X_test)

prob_y_1 = [p[1] for p in pred_proba]

cm_test = confusion_matrix(y_test, predictions)
cmap = plt.cm.Blues
plt.figure(figsize = (10,8))
plt.imshow(cm_test, interpolation='nearest', cmap=cmap)
title='Confusion matrix'
classes = ['No', 'Yes']
plt.title(title)

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=0)
plt.yticks(tick_marks, classes)

thresh = cm_test.max() / 2.
for i, j in itertools.product(range(cm_test.shape[0]), range(cm_test.shape[1])):
    plt.text(j, i, cm_test[i, j],
                 horizontalalignment="center",
                 color="white" if cm_test[i, j] > thresh else "black")

plt.tight_layout()
plt.grid(False)
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('PR AUC Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))

# %% [markdown]
# #### Evaluación del modelo con resample

# %%
# con SMOTE + RU


# define search
model = AutoSklearnClassifier(time_left_for_this_task=5*60, per_run_time_limit=30, n_jobs=8, metric=roc_auc)

# perform the search
model.fit(X_sm, y_sm)

# summarize
print(model.sprint_statistics())

# %%
predictions=model.predict(X_test_bp)

pred_proba=model.predict_proba(X_test_bp)

prob_y_1 = [p[1] for p in pred_proba]

cm_test = confusion_matrix(y_test, predictions)
cmap = plt.cm.Blues
plt.figure(figsize = (10,8))
plt.imshow(cm_test, interpolation='nearest', cmap=cmap)
title='Confusion matrix'
classes = ['No', 'Yes']
plt.title(title)

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=0)
plt.yticks(tick_marks, classes)

thresh = cm_test.max() / 2.
for i, j in itertools.product(range(cm_test.shape[0]), range(cm_test.shape[1])):
    plt.text(j, i, cm_test[i, j],
                 horizontalalignment="center",
                 color="white" if cm_test[i, j] > thresh else "black")

plt.tight_layout()
plt.grid(False)
plt.ylabel('True label')
plt.xlabel('Predicted label')

plt.show()

# %%
print('Accuray Score = {:0.3f}'.format(accuracy_score(y_test, predictions)))
      
print('AUC Score = {:0.3f}'.format(roc_auc_score(y_test, prob_y_1)) )

# calculate the precision-recall auc
precision, recall, _ = precision_recall_curve(y_test, prob_y_1)
auc_score = auc(recall, precision)
print('PR AUC Score = {:0.3f}'.format(auc_score))


# calculate the kappa score
print('Kappa Score = {:0.3f}'.format(cohen_kappa_score(y_test, predictions)))

# calculate the F1 score
print('F1 Score = {:0.3f}'.format(f1_score(y_test, predictions,average='binary')))

# calculate the recall score
print('Recall Score = {:0.3f}'.format(recall_score(y_test, predictions,average='binary')))

# calculate the precision score
print('Precision Score = {:0.3f}'.format(precision_score(y_test, predictions,average='binary')))
